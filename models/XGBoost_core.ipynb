# %%
import pandas as pd
import numpy as np
from pathlib import Path
from sklearn.preprocessing import MultiLabelBinarizer
from scipy.sparse import hstack
from sklearn.metrics import ndcg_score
import xgboost as xgb
import joblib

ROOT = Path.cwd().parents[0]
DATA = ROOT / "models"
OUT  = ROOT / "models"
OUT.mkdir(parents=True, exist_ok=True)

train = pd.read_csv(DATA / "train_core.csv")
test  = pd.read_csv(DATA / "test_core.csv")

print(f"Dataset sizes: train={len(train)}, test={len(test)}")
# Out:
# Dataset sizes: train=49500, test=5500

# %%
def to_list(s: str):
    return [x.strip().lower() for x in str(s).split(";") if x.strip()]

mlb_int = MultiLabelBinarizer(sparse_output=True)
mlb_tag = MultiLabelBinarizer(sparse_output=True)

X_train = hstack([
    mlb_int.fit_transform(train["interests"].map(to_list)),
    mlb_tag.fit_transform(train["core_program"].map(to_list))
], format="csr")
y_train = train["program_match"].values

X_test = hstack([
    mlb_int.transform(test["interests"].map(to_list)),
    mlb_tag.transform(test["core_program"].map(to_list))
], format="csr")
y_test  = test["program_match"].values

print("size", X_train.shape, X_test.shape)
# Out:
# size (49500, 35) (5500, 35)

# %%
params = {
    "objective": "reg:squarederror",
    "eval_metric": "rmse",
    "max_depth": 10,
    "eta": 0.1,
    "subsample": 0.8,
    "colsample_bytree": 0.8,
    "nthread": -1,
    "seed": 42
}

# %%
dtrain = xgb.DMatrix(X_train, label=y_train)
dtest  = xgb.DMatrix(X_test, label=y_test)

print("Training XGBoostRegressor ...")
evals = [(dtrain, "train"), (dtest, "test")]
model = xgb.train(params, dtrain, num_boost_round=300, evals=evals, verbose_eval=50)

test_pred = model.predict(dtest)
# Out:
# Training XGBoostRegressor ...
# [0]	train-rmse:0.11360	test-rmse:0.11631
# [50]	train-rmse:0.02348	test-rmse:0.02370
# [100]	train-rmse:0.01432	test-rmse:0.01542
# [150]	train-rmse:0.01084	test-rmse:0.01252
# [200]	train-rmse:0.00892	test-rmse:0.01097
# [250]	train-rmse:0.00764	test-rmse:0.00995
# [299]	train-rmse:0.00677	test-rmse:0.00927

# %%
model.save_model(OUT / "xgb_core_program_labelmatch_regressor.json")
print(f"Model saved: {OUT / 'xgb_core_program_labelmatch_regressor.json'}")

bundle = {
    "model": model,
    "mlb_int": mlb_int,
    "mlb_tag": mlb_tag,
}

joblib.dump(bundle, OUT / "xgb_core_program_labelmatch_regressor.pkl")
print(f"Bundle saved: {OUT / 'xgb_core_program_labelmatch_regressor.pkl'}")
# Out:
# Model saved: /Users/zyh/Desktop/HDG_group/models/xgb_core_program_labelmatch_regressor.json
# Bundle saved: /Users/zyh/Desktop/HDG_group/models/xgb_core_program_labelmatch_regressor.pkl

# %%
out_df = test.copy()
out_df["pred_program_match"] = np.round(test_pred, 4)
out_df.to_csv(OUT / "xgb_core_test.csv", index=False)

# %%
val_df = test[["student_id", "program_match"]].copy()
val_df["pred_program_match"] = np.asarray(test_pred, dtype=float)

rows = []
for sid, g in val_df.groupby("student_id", sort=True):
    y_true = g["program_match"].to_numpy().reshape(1, -1)
    y_pred = g["pred_program_match"].to_numpy().reshape(1, -1)
    rows.append({"student_id": sid, "nDCG@3": float(ndcg_score(y_true, y_pred, k=3))})

ndcg_XGB = pd.DataFrame(rows).sort_values("student_id").reset_index(drop=True)
mean_ndcg_XGB = float(ndcg_XGB["nDCG@3"].mean())

display(ndcg_XGB)
print("Mean nDCG@3", round(mean_ndcg_XGB, 6))
# Out:
#      student_id  nDCG@3
# 0            22     1.0
# 1            28     1.0
# 2            30     1.0
# 3            37     1.0
# 4            47     1.0
# ..          ...     ...
# 495        4912     1.0
# 496        4934     1.0
# 497        4955     1.0
# 498        4956     1.0
# 499        4996     1.0
#
# [500 rows x 2 columns]
# Mean nDCG@3 0.999271
